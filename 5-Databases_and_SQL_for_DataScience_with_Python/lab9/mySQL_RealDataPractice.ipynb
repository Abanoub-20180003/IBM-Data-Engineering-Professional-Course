# %% [markdown]
# # Working with a real world data-set using SQL and Python

# %% [markdown]
# ## Chicago Public Schools - Progress Report Cards (2011-2012)
#
# The city of Chicago released a dataset showing all school level performance data used to create School Report Cards for the 2011-2012 school year. The dataset is available from the Chicago Data Portal: [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# This dataset includes a large number of metrics. Start by familiarizing yourself with the types of metrics in the database: [https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?download=true](https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&download=true&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# **NOTE**:
#
# Do not download the dataset directly from City of Chicago portal. Instead download a static copy which is a more database friendly version from this <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">link</a>.
#
# Now review some of its contents.

# %% [markdown]
# ### Store the dataset in a Table
#
# it is easier to read the dataset into a Pandas dataframe and then PERSIST it into the database. But it results in mapping to default datatypes which may not be optimal for SQL querying.
#
# Therefore, **it is highly recommended to manually load the table using the database console LOAD tool**

# %% [markdown]
# ### Connect to Database

# %%
import pymysql
import pandas as pd 
# %load_ext sql

# %%
from pymysql import Error
try:
    connection = pymysql.connect(
        host = 'localhost',
        user = 'root',
        password = '',
        database = 'mysql_learners'
    )
except Error as e:
    print("Connect to DB Filed")
else:
    print("Connect to DB Succeded")
# Out:
# Connect to DB Succeded

# %%
# Create Database Engine by sqlalchemy used by panads to connect database
import sqlalchemy as sq
try:
    DB_Engine = sq.create_engine("mysql+pymysql://root:@localhost/mysql_learners")
    
except Error as e:
    print("Connect to DB Filed")
else:
    print("Connect to DB Succeded")
# Out:
# Connect to DB Succeded

# %% [markdown]
# ### Query the database system catalog to retrieve table metadata

# %%
# type in your query to retrieve list of all tables in the database
metadata = 'SELECT * FROM INFORMATION_SCHEMA.TABLES;'

#get connection cursor 

try:
    cursor = connection.cursor()
    
except Error as e:
    print("cusrdor object Filed")
else:
    print("cusrdor object Succeded")
# Out:
# cusrdor object Succeded

# %%
try:
    cursor.execute(metadata)
    
except Error as e:
    print("select query Filed")
else:
    print("select query Succeded")
# Out:
# select query Succeded

# %%
#print tables 
tables = cursor.fetchall()

for table in tables:
    print(table)
# Out:
# ('def', 'mysql', 'innodb_table_stats', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 43, 381, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 14, 39, 45), datetime.datetime(2022, 2, 28, 17, 56, 1), None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', '')
# ('def', 'mysql', 'innodb_index_stats', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 151, 325, 49152, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 14, 39, 45), datetime.datetime(2022, 2, 28, 17, 56, 1), None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', '')
# ('def', 'information_schema', 'CHARACTER_SETS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'CHECK_CONSTRAINTS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'COLLATIONS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'COLLATION_CHARACTER_SET_APPLICABILITY', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'COLUMNS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'COLUMNS_EXTENSIONS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'COLUMN_STATISTICS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'EVENTS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'FILES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_DATAFILES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_FOREIGN', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_FOREIGN_COLS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_FIELDS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_TABLESPACES_BRIEF', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'KEYWORDS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'PARAMETERS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'PARTITIONS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'RESOURCE_GROUPS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'ROUTINES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'SCHEMATA', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'SCHEMATA_EXTENSIONS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'ST_SPATIAL_REFERENCE_SYSTEMS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'ST_UNITS_OF_MEASURE', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'ST_GEOMETRY_COLUMNS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'STATISTICS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'TABLE_CONSTRAINTS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'TABLE_CONSTRAINTS_EXTENSIONS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'TABLES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'TABLES_EXTENSIONS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'TABLESPACES_EXTENSIONS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'TRIGGERS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'VIEW_ROUTINE_USAGE', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'VIEW_TABLE_USAGE', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'VIEWS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'COLUMN_PRIVILEGES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'ENGINES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'OPTIMIZER_TRACE', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'PLUGINS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'PROCESSLIST', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'PROFILING', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'SCHEMA_PRIVILEGES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'TABLESPACES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'TABLE_PRIVILEGES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'information_schema', 'USER_PRIVILEGES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, None, None, '', '')
# ('def', 'performance_schema', 'cond_instances', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'error_log', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 126, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_waits_current', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 1536, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_waits_history', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 2560, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_waits_history_long', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 10000, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_waits_summary_by_host_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 83712, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_waits_summary_by_instance', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 10752, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_waits_summary_by_thread_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 167424, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_waits_summary_by_user_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 83712, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_waits_summary_by_account_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 83712, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_waits_summary_global_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 654, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'file_instances', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 4096, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'file_summary_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 80, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'file_summary_by_instance', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 4096, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'host_cache', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 279, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'mutex_instances', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 4096, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'objects_summary_global_by_type', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 4096, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'performance_timers', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Fixed', 5, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'processlist', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'rwlock_instances', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 2048, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'setup_actors', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Fixed', 128, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'setup_consumers', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 16, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'setup_instruments', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 1500, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'setup_objects', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 128, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'setup_threads', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 100, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'table_io_waits_summary_by_index_usage', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 8192, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'table_io_waits_summary_by_table', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 4096, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'table_lock_waits_summary_by_table', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 4096, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'threads', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_stages_current', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_stages_history', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 2560, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_stages_history_long', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 10000, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_stages_summary_by_thread_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 44800, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_stages_summary_by_account_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 22400, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_stages_summary_by_user_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 22400, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_stages_summary_by_host_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 22400, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_stages_summary_global_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 175, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_statements_current', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 2560, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_statements_history', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 2560, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_statements_history_long', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 10000, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_statements_summary_by_thread_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 56064, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_statements_summary_by_account_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 28032, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_statements_summary_by_user_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 28032, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_statements_summary_by_host_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 28032, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_statements_summary_global_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 219, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_statements_summary_by_digest', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 10000, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_statements_summary_by_program', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_statements_histogram_global', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Fixed', 450, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_statements_histogram_by_digest', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 10000, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_transactions_current', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_transactions_history', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 2560, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_transactions_history_long', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 10000, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_transactions_summary_by_thread_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_transactions_summary_by_account_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 128, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_transactions_summary_by_user_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 128, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_transactions_summary_by_host_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 128, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_transactions_summary_global_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 1, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_errors_summary_by_user_by_error', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 200192, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_errors_summary_by_host_by_error', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 200192, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_errors_summary_by_account_by_error', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 200192, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_errors_summary_by_thread_by_error', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 400384, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'events_errors_summary_global_by_error', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 5035, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'users', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Fixed', 128, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'accounts', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Fixed', 128, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'hosts', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Fixed', 128, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'socket_instances', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'socket_summary_by_instance', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'socket_summary_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 10, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'session_connect_attrs', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 131072, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_bin', None, '', '')
# ('def', 'performance_schema', 'session_account_connect_attrs', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 131072, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_bin', None, '', '')
# ('def', 'performance_schema', 'keyring_keys', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 96, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_bin', None, '', '')
# ('def', 'performance_schema', 'memory_summary_global_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 450, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'memory_summary_by_account_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 57600, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'memory_summary_by_host_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 57600, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'memory_summary_by_thread_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 115200, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'memory_summary_by_user_by_event_name', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 57600, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'table_handles', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 1024, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'metadata_locks', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 1024, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'data_locks', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 99999, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'data_lock_waits', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 99999, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'replication_connection_configuration', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'replication_group_members', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Fixed', 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'replication_connection_status', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'replication_applier_configuration', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'replication_applier_status', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Fixed', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'replication_applier_status_by_coordinator', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'replication_applier_status_by_worker', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 8192, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'replication_group_member_stats', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'replication_applier_filters', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'replication_applier_global_filters', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'replication_asynchronous_connection_failover', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Fixed', 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'replication_asynchronous_connection_failover_managed', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'log_status', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 1, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'prepared_statements_instances', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'user_variables_by_thread', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 2560, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'status_by_account', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 32256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'status_by_host', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 32256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'status_by_thread', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 64512, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'status_by_user', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 32256, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'global_status', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 252, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'session_status', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 252, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'variables_by_thread', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 170240, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'global_variables', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 665, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'session_variables', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 665, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'variables_info', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 665, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'persisted_variables', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'user_defined_functions', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 13, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'binary_log_transaction_compression_stats', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'tls_channel_status', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 96, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'performance_schema', 'keyring_component_status', 'BASE TABLE', 'PERFORMANCE_SCHEMA', 10, 'Dynamic', 64, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 47), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'mysql', 'db', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 2, 8192, 16384, 0, 16384, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', 'Database privileges')
# ('def', 'mysql', 'user', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 4, 4096, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', 'Users and global privileges')
# ('def', 'mysql', 'default_roles', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', 'Default roles')
# ('def', 'mysql', 'role_edges', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', 'Role hierarchy and role grants')
# ('def', 'mysql', 'global_grants', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 47, 1045, 49152, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', 'Extended global grants')
# ('def', 'mysql', 'password_history', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', 'Password history for user accounts')
# ('def', 'mysql', 'func', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', 'User defined functions')
# ('def', 'mysql', 'plugin', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'MySQL plugins')
# ('def', 'mysql', 'help_topic', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 774, 2053, 1589248, 0, 98304, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'help topics')
# ('def', 'mysql', 'help_category', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 53, 309, 16384, 0, 16384, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'help categories')
# ('def', 'mysql', 'help_relation', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 2871, 34, 98304, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'keyword-topic relation')
# ('def', 'mysql', 'servers', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'MySQL Foreign Servers table')
# ('def', 'mysql', 'tables_priv', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 2, 8192, 16384, 0, 16384, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', 'Table privileges')
# ('def', 'mysql', 'columns_priv', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', 'Column privileges')
# ('def', 'mysql', 'help_keyword', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 833, 157, 131072, 0, 131072, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'help keywords')
# ('def', 'mysql', 'time_zone_name', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'Time zone names')
# ('def', 'mysql', 'time_zone', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, 1, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'Time zones')
# ('def', 'mysql', 'time_zone_transition', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'Time zone transitions')
# ('def', 'mysql', 'time_zone_transition_type', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'Time zone transition types')
# ('def', 'mysql', 'time_zone_leap_second', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'Leap seconds information for time zones')
# ('def', 'mysql', 'procs_priv', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 16384, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', 'Procedure privileges')
# ('def', 'mysql', 'general_log', 'BASE TABLE', 'CSV', 10, 'Dynamic', 2, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, '', 'General log')
# ('def', 'mysql', 'slow_log', 'BASE TABLE', 'CSV', 10, 'Dynamic', 2, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, '', 'Slow log')
# ('def', 'mysql', 'component', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, 1, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC', 'Components')
# ('def', 'mysql', 'slave_relay_log_info', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'Relay Log Information')
# ('def', 'mysql', 'slave_master_info', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'Master Information')
# ('def', 'mysql', 'slave_worker_info', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'Worker Information')
# ('def', 'mysql', 'gtid_executed', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8mb4_0900_ai_ci', None, 'row_format=DYNAMIC stats_persistent=0', '')
# ('def', 'mysql', 'replication_asynchronous_connection_failover', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 16384, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'The source configuration details')
# ('def', 'mysql', 'replication_asynchronous_connection_failover_managed', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'The managed source configuration details')
# ('def', 'mysql', 'replication_group_member_actions', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 2, 8192, 16384, 0, 16384, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8mb4_0900_ai_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'The member actions configuration.')
# ('def', 'mysql', 'replication_group_configuration_version', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 1, 16384, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8mb4_0900_ai_ci', None, 'row_format=DYNAMIC stats_persistent=0', 'The group configuration version.')
# ('def', 'mysql', 'server_cost', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 6, 2730, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', '')
# ('def', 'mysql', 'engine_cost', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 2, 8192, 16384, 0, 0, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_general_ci', None, 'row_format=DYNAMIC stats_persistent=0', '')
# ('def', 'mysql', 'proxies_priv', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 1, 16384, 16384, 0, 16384, 4194304, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, 'utf8_bin', None, 'row_format=DYNAMIC stats_persistent=0', 'User proxy privileges')
# ('def', 'sys', 'version', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 49), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'sys_config', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 6, 2730, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'sys', 'innodb_buffer_stats_by_schema', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$innodb_buffer_stats_by_schema', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'innodb_buffer_stats_by_table', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$innodb_buffer_stats_by_table', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'schema_object_overview', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'schema_auto_increment_columns', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$schema_flattened_keys', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'schema_redundant_indexes', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'ps_check_lost_instrumentation', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'latest_file_io', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$latest_file_io', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'io_by_thread_by_latency', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$io_by_thread_by_latency', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'io_global_by_file_by_bytes', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$io_global_by_file_by_bytes', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'io_global_by_file_by_latency', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$io_global_by_file_by_latency', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'io_global_by_wait_by_bytes', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$io_global_by_wait_by_bytes', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'io_global_by_wait_by_latency', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$io_global_by_wait_by_latency', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'innodb_lock_waits', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$innodb_lock_waits', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ...
# ('def', 'sys', 'x$waits_by_host_by_latency', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'waits_global_by_latency', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$waits_global_by_latency', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'metrics', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'processlist', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$processlist', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'session', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'x$session', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'sys', 'session_ssl_status', 'VIEW', None, None, None, None, None, None, None, None, None, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, None, 'VIEW')
# ('def', 'information_schema', 'ENABLED_ROLES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, '', '')
# ('def', 'information_schema', 'APPLICABLE_ROLES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, '', '')
# ('def', 'information_schema', 'ADMINISTRABLE_ROLE_AUTHORIZATIONS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, '', '')
# ('def', 'information_schema', 'ROLE_COLUMN_GRANTS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, '', '')
# ('def', 'information_schema', 'ROLE_ROUTINE_GRANTS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, '', '')
# ('def', 'information_schema', 'ROLE_TABLE_GRANTS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, '', '')
# ('def', 'information_schema', 'USER_ATTRIBUTES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 39, 50), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_CMP', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_CMPMEM', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_TRX', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_CMP_PER_INDEX', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_CMP_RESET', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_FT_DELETED', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_BUFFER_POOL_STATS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_CMPMEM_RESET', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_BUFFER_PAGE_LRU', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_CMP_PER_INDEX_RESET', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_FT_CONFIG', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_BUFFER_PAGE', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_TABLESPACES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_FT_BEING_DELETED', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_TEMP_TABLE_INFO', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_FT_DEFAULT_STOPWORD', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_METRICS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_FT_INDEX_CACHE', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_FT_INDEX_TABLE', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_TABLES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_TABLESTATS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_INDEXES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_COLUMNS', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_VIRTUAL', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_CACHED_INDEXES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'information_schema', 'INNODB_SESSION_TEMP_TABLESPACES', 'SYSTEM VIEW', None, 10, None, 0, 0, 0, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 46, 5), None, None, None, None, '', '')
# ('def', 'ebooks', 'book_genres', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 3064, 48, 147456, 0, 81920, 0, None, datetime.datetime(2022, 2, 12, 16, 49, 1), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'ebooks', 'books', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 1091, 135, 147456, 0, 16384, 0, None, datetime.datetime(2022, 2, 12, 16, 49, 1), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'ebooks', 'genres', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 69, 237, 16384, 0, 16384, 0, None, datetime.datetime(2022, 2, 12, 16, 49, 1), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'ebooks', 'publishers', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 193, 84, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 49, 1), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'phpmyadmin', 'pma__bookmark', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, 1, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Bookmarks')
# ('def', 'phpmyadmin', 'pma__relation', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 16384, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Relation table')
# ('def', 'phpmyadmin', 'pma__table_info', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Table information for phpMyAdmin')
# ('def', 'phpmyadmin', 'pma__table_coords', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Table coordinates for phpMyAdmin PDF output')
# ('def', 'phpmyadmin', 'pma__pdf_pages', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 16384, 0, 1, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'PDF relation pages for phpMyAdmin')
# ('def', 'phpmyadmin', 'pma__column_info', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 16384, 0, 1, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Column information for phpMyAdmin')
# ('def', 'phpmyadmin', 'pma__history', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 16384, 0, 1, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'SQL history for phpMyAdmin')
# ('def', 'phpmyadmin', 'pma__recent', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), datetime.datetime(2022, 2, 28, 17, 48, 48), None, 'utf8_bin', None, '', 'Recently accessed tables')
# ('def', 'phpmyadmin', 'pma__favorite', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Favorite tables')
# ('def', 'phpmyadmin', 'pma__table_uiprefs', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 1, 16384, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), datetime.datetime(2022, 2, 28, 17, 50, 41), None, 'utf8_bin', None, '', "Tables' UI preferences")
# ('def', 'phpmyadmin', 'pma__tracking', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Database changes tracking for phpMyAdmin')
# ('def', 'phpmyadmin', 'pma__userconfig', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), datetime.datetime(2022, 2, 28, 17, 55, 57), None, 'utf8_bin', None, '', 'User preferences storage for phpMyAdmin')
# ('def', 'phpmyadmin', 'pma__users', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Users and their assignments to user groups')
# ('def', 'phpmyadmin', 'pma__usergroups', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'User groups with configured menu items')
# ('def', 'phpmyadmin', 'pma__navigationhiding', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Hidden items of navigation tree')
# ('def', 'phpmyadmin', 'pma__savedsearches', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 16384, 0, 1, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Saved searches')
# ('def', 'phpmyadmin', 'pma__central_columns', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Central list of columns')
# ('def', 'phpmyadmin', 'pma__designer_settings', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Settings related to Designer')
# ('def', 'phpmyadmin', 'pma__export_templates', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 16384, 0, 1, datetime.datetime(2022, 2, 12, 16, 58, 43), None, None, 'utf8_bin', None, '', 'Saved export templates')
# ('def', 'ebooks', 'authors', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 1378, 59, 81920, 0, 0, 0, 1391, datetime.datetime(2022, 2, 12, 17, 14, 16), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'ebooks', 'book_authors', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 1717, 47, 81920, 0, 49152, 0, None, datetime.datetime(2022, 2, 12, 17, 19, 30), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'coffee_shop_products', 'product_info_m-view', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 89, 184, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 14, 15, 55, 15), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'filmlocation', 'filmlocations', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 3307, 480, 1589248, 0, 0, 0, None, datetime.datetime(2022, 2, 15, 13, 56, 3), None, None, 'utf8_general_ci', None, '', '')
# ('def', 'pet_db', 'pet', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 3, 5461, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 21, 23, 21, 29), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'pet_db', 'petsale', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 5, 3276, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 21, 23, 48, 38), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'hr', 'employees', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 10, 1638, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 22, 15, 3, 1), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'hr', 'job_history', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 10, 1638, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 22, 15, 3, 1), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'hr', 'jobs', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 10, 1638, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 22, 15, 3, 1), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'hr', 'departments', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 2, 8192, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 22, 15, 3, 1), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'hr', 'locations', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 2, 8192, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 22, 15, 3, 1), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'mysql_learners', 'petrescue', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 9, 1820, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 23, 15, 12, 22), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'mysql_learners', 'instructor', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 3, 5461, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 24, 18, 40, 37), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'mysql_learners', 'international_student_test_scores', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 99, 165, 16384, 0, 0, 0, None, datetime.datetime(2022, 2, 24, 20, 12, 34), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'mysql_learners', 'chicago_socioeconomic_data', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 78, 210, 16384, 0, 16384, 0, None, datetime.datetime(2022, 2, 27, 15, 52, 53), None, None, 'utf8mb4_0900_ai_ci', None, '', '')
# ('def', 'mysql_learners', 'chicagopublicschools', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 86, 1143, 98304, 0, 0, 0, None, datetime.datetime(2022, 2, 28, 17, 54, 8), None, None, 'utf8_general_ci', None, '', '')

# %% [markdown]
# ### Query the database system catalog to retrieve column metadata

# %%
metadata = 'SELECT * FROM INFORMATION_SCHEMA.COLUMNS;'
try:
    cursor.execute(metadata)
    
except Error as e:
    print("select query Filed")
else:
    print("select query Succeded")
# Out:
# select query Succeded

# %%
columns = cursor.fetchall()

for column in columns:
    print(column)
# Out:
# ('def', 'mysql', 'innodb_table_stats', 'database_name', 1, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_bin', 'varchar(64)', 'PRI', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_table_stats', 'table_name', 2, None, 'NO', 'varchar', 199, 597, None, None, None, 'utf8', 'utf8_bin', 'varchar(199)', 'PRI', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_table_stats', 'last_update', 3, 'CURRENT_TIMESTAMP', 'NO', 'timestamp', None, None, None, None, 0, None, None, 'timestamp', '', 'DEFAULT_GENERATED on update CURRENT_TIMESTAMP', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_table_stats', 'n_rows', 4, None, 'NO', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_table_stats', 'clustered_index_size', 5, None, 'NO', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_table_stats', 'sum_of_other_index_sizes', 6, None, 'NO', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_index_stats', 'database_name', 1, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_bin', 'varchar(64)', 'PRI', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_index_stats', 'table_name', 2, None, 'NO', 'varchar', 199, 597, None, None, None, 'utf8', 'utf8_bin', 'varchar(199)', 'PRI', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_index_stats', 'index_name', 3, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_bin', 'varchar(64)', 'PRI', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_index_stats', 'last_update', 4, 'CURRENT_TIMESTAMP', 'NO', 'timestamp', None, None, None, None, 0, None, None, 'timestamp', '', 'DEFAULT_GENERATED on update CURRENT_TIMESTAMP', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_index_stats', 'stat_name', 5, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_bin', 'varchar(64)', 'PRI', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_index_stats', 'stat_value', 6, None, 'NO', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_index_stats', 'sample_size', 7, None, 'YES', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql', 'innodb_index_stats', 'stat_description', 8, None, 'NO', 'varchar', 1024, 3072, None, None, None, 'utf8', 'utf8_bin', 'varchar(1024)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'information_schema', 'CHARACTER_SETS', 'CHARACTER_SET_NAME', 1, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'CHARACTER_SETS', 'DEFAULT_COLLATE_NAME', 2, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'CHARACTER_SETS', 'DESCRIPTION', 3, None, 'NO', 'varchar', 2048, 6144, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(2048)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'CHARACTER_SETS', 'MAXLEN', 4, None, 'NO', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'CHECK_CONSTRAINTS', 'CONSTRAINT_CATALOG', 1, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'CHECK_CONSTRAINTS', 'CONSTRAINT_SCHEMA', 2, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'CHECK_CONSTRAINTS', 'CONSTRAINT_NAME', 3, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'CHECK_CONSTRAINTS', 'CHECK_CLAUSE', 4, None, 'NO', 'longtext', 4294967295, 4294967295, None, None, None, 'utf8', 'utf8_bin', 'longtext', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLLATIONS', 'COLLATION_NAME', 1, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLLATIONS', 'CHARACTER_SET_NAME', 2, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLLATIONS', 'ID', 3, '0', 'NO', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLLATIONS', 'IS_DEFAULT', 4, '', 'NO', 'varchar', 3, 9, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(3)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLLATIONS', 'IS_COMPILED', 5, '', 'NO', 'varchar', 3, 9, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(3)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLLATIONS', 'SORTLEN', 6, None, 'NO', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLLATIONS', 'PAD_ATTRIBUTE', 7, None, 'NO', 'enum', 9, 27, None, None, None, 'utf8', 'utf8_bin', "enum('PAD SPACE','NO PAD')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLLATION_CHARACTER_SET_APPLICABILITY', 'COLLATION_NAME', 1, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLLATION_CHARACTER_SET_APPLICABILITY', 'CHARACTER_SET_NAME', 2, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'TABLE_CATALOG', 1, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'TABLE_SCHEMA', 2, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'TABLE_NAME', 3, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'COLUMN_NAME', 4, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'ORDINAL_POSITION', 5, None, 'NO', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'COLUMN_DEFAULT', 6, None, 'YES', 'text', 65535, 65535, None, None, None, 'utf8', 'utf8_bin', 'text', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'IS_NULLABLE', 7, '', 'NO', 'varchar', 3, 9, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(3)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'DATA_TYPE', 8, None, 'YES', 'longtext', 4294967295, 4294967295, None, None, None, 'utf8', 'utf8_bin', 'longtext', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'CHARACTER_MAXIMUM_LENGTH', 9, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'CHARACTER_OCTET_LENGTH', 10, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'NUMERIC_PRECISION', 11, None, 'YES', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'NUMERIC_SCALE', 12, None, 'YES', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'DATETIME_PRECISION', 13, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'CHARACTER_SET_NAME', 14, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'COLLATION_NAME', 15, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'COLUMN_TYPE', 16, None, 'NO', 'mediumtext', 16777215, 16777215, None, None, None, 'utf8', 'utf8_bin', 'mediumtext', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'COLUMN_KEY', 17, None, 'NO', 'enum', 3, 9, None, None, None, 'utf8', 'utf8_bin', "enum('','PRI','UNI','MUL')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'EXTRA', 18, None, 'YES', 'varchar', 256, 768, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(256)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'PRIVILEGES', 19, None, 'YES', 'varchar', 154, 462, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(154)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'COLUMN_COMMENT', 20, None, 'NO', 'text', 65535, 65535, None, None, None, 'utf8', 'utf8_bin', 'text', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'GENERATION_EXPRESSION', 21, None, 'NO', 'longtext', 4294967295, 4294967295, None, None, None, 'utf8', 'utf8_bin', 'longtext', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS', 'SRS_ID', 22, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS_EXTENSIONS', 'TABLE_CATALOG', 1, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS_EXTENSIONS', 'TABLE_SCHEMA', 2, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS_EXTENSIONS', 'TABLE_NAME', 3, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS_EXTENSIONS', 'COLUMN_NAME', 4, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS_EXTENSIONS', 'ENGINE_ATTRIBUTE', 5, None, 'YES', 'json', None, None, None, None, None, None, None, 'json', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMNS_EXTENSIONS', 'SECONDARY_ENGINE_ATTRIBUTE', 6, None, 'YES', 'json', None, None, None, None, None, None, None, 'json', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMN_STATISTICS', 'SCHEMA_NAME', 1, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMN_STATISTICS', 'TABLE_NAME', 2, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMN_STATISTICS', 'COLUMN_NAME', 3, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'COLUMN_STATISTICS', 'HISTOGRAM', 4, None, 'NO', 'json', None, None, None, None, None, None, None, 'json', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'EVENT_CATALOG', 1, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'EVENT_SCHEMA', 2, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'EVENT_NAME', 3, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'DEFINER', 4, None, 'NO', 'varchar', 288, 864, None, None, None, 'utf8', 'utf8_bin', 'varchar(288)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'TIME_ZONE', 5, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_bin', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'EVENT_BODY', 6, '', 'NO', 'varchar', 3, 9, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(3)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'EVENT_DEFINITION', 7, None, 'NO', 'longtext', 4294967295, 4294967295, None, None, None, 'utf8', 'utf8_bin', 'longtext', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'EVENT_TYPE', 8, '', 'NO', 'varchar', 9, 27, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(9)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'EXECUTE_AT', 9, None, 'YES', 'datetime', None, None, None, None, 0, None, None, 'datetime', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'INTERVAL_VALUE', 10, None, 'YES', 'varchar', 256, 768, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(256)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'INTERVAL_FIELD', 11, None, 'YES', 'enum', 18, 54, None, None, None, 'utf8', 'utf8_bin', "enum('YEAR','QUARTER','MONTH','DAY','HOUR','MINUTE','WEEK','SECOND','MICROSECOND','YEAR_MONTH','DAY_HOUR','DAY_MINUTE','DAY_SECOND','HOUR_MINUTE','HOUR_SECOND','MINUTE_SECOND','DAY_MICROSECOND','HOUR_MICROSECOND','MINUTE_MICROSECOND','SECOND_MICROSECOND')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'SQL_MODE', 12, None, 'NO', 'set', 520, 1560, None, None, None, 'utf8', 'utf8_bin', "set('REAL_AS_FLOAT','PIPES_AS_CONCAT','ANSI_QUOTES','IGNORE_SPACE','NOT_USED','ONLY_FULL_GROUP_BY','NO_UNSIGNED_SUBTRACTION','NO_DIR_IN_CREATE','NOT_USED_9','NOT_USED_10','NOT_USED_11','NOT_USED_12','NOT_USED_13','NOT_USED_14','NOT_USED_15','NOT_USED_16','NOT_USED_17','NOT_USED_18','ANSI','NO_AUTO_VALUE_ON_ZERO','NO_BACKSLASH_ESCAPES','STRICT_TRANS_TABLES','STRICT_ALL_TABLES','NO_ZERO_IN_DATE','NO_ZERO_DATE','ALLOW_INVALID_DATES','ERROR_FOR_DIVISION_BY_ZERO','TRADITIONAL','NOT_USED_29','HIGH_NOT_PRECEDENCE','NO_ENGINE_SUBSTITUTION','PAD_CHAR_TO_FULL_LENGTH','TIME_TRUNCATE_FRACTIONAL')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'STARTS', 13, None, 'YES', 'datetime', None, None, None, None, 0, None, None, 'datetime', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'ENDS', 14, None, 'YES', 'datetime', None, None, None, None, 0, None, None, 'datetime', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'STATUS', 15, None, 'NO', 'enum', 18, 54, None, None, None, 'utf8', 'utf8_bin', "enum('ENABLED','DISABLED','SLAVESIDE_DISABLED')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'ON_COMPLETION', 16, '', 'NO', 'varchar', 12, 36, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(12)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'CREATED', 17, None, 'NO', 'timestamp', None, None, None, None, 0, None, None, 'timestamp', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'LAST_ALTERED', 18, None, 'NO', 'timestamp', None, None, None, None, 0, None, None, 'timestamp', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'LAST_EXECUTED', 19, None, 'YES', 'datetime', None, None, None, None, 0, None, None, 'datetime', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'EVENT_COMMENT', 20, None, 'NO', 'varchar', 2048, 6144, None, None, None, 'utf8', 'utf8_bin', 'varchar(2048)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'ORIGINATOR', 21, None, 'NO', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'CHARACTER_SET_CLIENT', 22, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'COLLATION_CONNECTION', 23, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'EVENTS', 'DATABASE_COLLATION', 24, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'FILE_ID', 1, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'FILE_NAME', 2, None, 'YES', 'text', 65535, 65535, None, None, None, 'utf8', 'utf8_bin', 'text', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'FILE_TYPE', 3, None, 'YES', 'varchar', 256, 768, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(256)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'TABLESPACE_NAME', 4, None, 'NO', 'varchar', 268, 804, None, None, None, 'utf8', 'utf8_bin', 'varchar(268)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'TABLE_CATALOG', 5, '', 'NO', 'char', 0, 0, None, None, None, 'utf8', 'utf8_general_ci', 'char(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'TABLE_SCHEMA', 6, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'TABLE_NAME', 7, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'LOGFILE_GROUP_NAME', 8, None, 'YES', 'varchar', 256, 768, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(256)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'LOGFILE_GROUP_NUMBER', 9, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'ENGINE', 10, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'FULLTEXT_KEYS', 11, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'DELETED_ROWS', 12, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'UPDATE_COUNT', 13, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'FREE_EXTENTS', 14, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'TOTAL_EXTENTS', 15, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'EXTENT_SIZE', 16, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'INITIAL_SIZE', 17, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'MAXIMUM_SIZE', 18, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'AUTOEXTEND_SIZE', 19, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'CREATION_TIME', 20, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'LAST_UPDATE_TIME', 21, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'LAST_ACCESS_TIME', 22, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'RECOVER_TIME', 23, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'TRANSACTION_COUNTER', 24, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'VERSION', 25, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'ROW_FORMAT', 26, None, 'YES', 'varchar', 256, 768, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(256)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'TABLE_ROWS', 27, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'AVG_ROW_LENGTH', 28, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'DATA_LENGTH', 29, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'MAX_DATA_LENGTH', 30, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'INDEX_LENGTH', 31, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'DATA_FREE', 32, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'CREATE_TIME', 33, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'UPDATE_TIME', 34, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'CHECK_TIME', 35, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'CHECKSUM', 36, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'STATUS', 37, None, 'YES', 'varchar', 256, 768, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(256)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'FILES', 'EXTRA', 38, None, 'YES', 'varchar', 256, 768, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(256)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_DATAFILES', 'SPACE', 1, None, 'YES', 'varbinary', 256, 256, None, None, None, None, None, 'varbinary(256)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_DATAFILES', 'PATH', 2, None, 'NO', 'varchar', 512, 1536, None, None, None, 'utf8', 'utf8_bin', 'varchar(512)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_FOREIGN', 'ID', 1, None, 'YES', 'varchar', 129, 387, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(129)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_FOREIGN', 'FOR_NAME', 2, None, 'YES', 'varchar', 129, 387, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(129)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_FOREIGN', 'REF_NAME', 3, None, 'YES', 'varchar', 129, 387, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(129)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_FOREIGN', 'N_COLS', 4, '0', 'NO', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_FOREIGN', 'TYPE', 5, '0', 'NO', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_FOREIGN_COLS', 'ID', 1, None, 'YES', 'varchar', 129, 387, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(129)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_FOREIGN_COLS', 'FOR_COL_NAME', 2, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_FOREIGN_COLS', 'REF_COL_NAME', 3, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_FOREIGN_COLS', 'POS', 4, None, 'NO', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_FIELDS', 'INDEX_ID', 1, None, 'YES', 'varbinary', 256, 256, None, None, None, None, None, 'varbinary(256)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_FIELDS', 'NAME', 2, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_FIELDS', 'POS', 3, '0', 'NO', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_TABLESPACES_BRIEF', 'SPACE', 1, None, 'YES', 'varbinary', 256, 256, None, None, None, None, None, 'varbinary(256)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_TABLESPACES_BRIEF', 'NAME', 2, None, 'NO', 'varchar', 268, 804, None, None, None, 'utf8', 'utf8_bin', 'varchar(268)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_TABLESPACES_BRIEF', 'PATH', 3, None, 'NO', 'varchar', 512, 1536, None, None, None, 'utf8', 'utf8_bin', 'varchar(512)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_TABLESPACES_BRIEF', 'FLAG', 4, None, 'YES', 'varbinary', 256, 256, None, None, None, None, None, 'varbinary(256)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'INNODB_TABLESPACES_BRIEF', 'SPACE_TYPE', 5, '', 'NO', 'varchar', 7, 21, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(7)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'CONSTRAINT_CATALOG', 1, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'CONSTRAINT_SCHEMA', 2, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'CONSTRAINT_NAME', 3, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'TABLE_CATALOG', 4, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'TABLE_SCHEMA', 5, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'TABLE_NAME', 6, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'COLUMN_NAME', 7, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'ORDINAL_POSITION', 8, '0', 'NO', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'POSITION_IN_UNIQUE_CONSTRAINT', 9, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'REFERENCED_TABLE_SCHEMA', 10, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'REFERENCED_TABLE_NAME', 11, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'REFERENCED_COLUMN_NAME', 12, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEYWORDS', 'WORD', 1, None, 'YES', 'varchar', 128, 512, None, None, None, 'utf8mb4', 'utf8mb4_0900_ai_ci', 'varchar(128)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'KEYWORDS', 'RESERVED', 2, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'SPECIFIC_CATALOG', 1, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'SPECIFIC_SCHEMA', 2, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'SPECIFIC_NAME', 3, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'ORDINAL_POSITION', 4, '0', 'NO', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'PARAMETER_MODE', 5, None, 'YES', 'varchar', 5, 15, None, None, None, 'utf8', 'utf8_bin', 'varchar(5)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'PARAMETER_NAME', 6, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'DATA_TYPE', 7, None, 'YES', 'longtext', 4294967295, 4294967295, None, None, None, 'utf8', 'utf8_bin', 'longtext', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'CHARACTER_MAXIMUM_LENGTH', 8, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'CHARACTER_OCTET_LENGTH', 9, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'NUMERIC_PRECISION', 10, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'NUMERIC_SCALE', 11, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'DATETIME_PRECISION', 12, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'CHARACTER_SET_NAME', 13, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'COLLATION_NAME', 14, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'DTD_IDENTIFIER', 15, None, 'NO', 'mediumtext', 16777215, 16777215, None, None, None, 'utf8', 'utf8_bin', 'mediumtext', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARAMETERS', 'ROUTINE_TYPE', 16, None, 'NO', 'enum', 9, 27, None, None, None, 'utf8', 'utf8_bin', "enum('FUNCTION','PROCEDURE')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'TABLE_CATALOG', 1, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'TABLE_SCHEMA', 2, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'TABLE_NAME', 3, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'PARTITION_NAME', 4, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'SUBPARTITION_NAME', 5, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'PARTITION_ORDINAL_POSITION', 6, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'SUBPARTITION_ORDINAL_POSITION', 7, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'PARTITION_METHOD', 8, None, 'YES', 'varchar', 13, 39, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(13)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'SUBPARTITION_METHOD', 9, None, 'YES', 'varchar', 13, 39, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(13)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'PARTITION_EXPRESSION', 10, None, 'YES', 'varchar', 2048, 6144, None, None, None, 'utf8', 'utf8_bin', 'varchar(2048)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'SUBPARTITION_EXPRESSION', 11, None, 'YES', 'varchar', 2048, 6144, None, None, None, 'utf8', 'utf8_bin', 'varchar(2048)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'PARTITION_DESCRIPTION', 12, None, 'YES', 'text', 65535, 65535, None, None, None, 'utf8', 'utf8_bin', 'text', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'TABLE_ROWS', 13, None, 'YES', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'AVG_ROW_LENGTH', 14, None, 'YES', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'DATA_LENGTH', 15, None, 'YES', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'MAX_DATA_LENGTH', 16, None, 'YES', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'INDEX_LENGTH', 17, None, 'YES', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'DATA_FREE', 18, None, 'YES', 'bigint', None, None, 20, 0, None, None, None, 'bigint unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'CREATE_TIME', 19, None, 'NO', 'timestamp', None, None, None, None, 0, None, None, 'timestamp', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'UPDATE_TIME', 20, None, 'YES', 'datetime', None, None, None, None, 0, None, None, 'datetime', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'CHECK_TIME', 21, None, 'YES', 'datetime', None, None, None, None, 0, None, None, 'datetime', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'CHECKSUM', 22, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'PARTITION_COMMENT', 23, None, 'NO', 'text', 65535, 65535, None, None, None, 'utf8', 'utf8_bin', 'text', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'NODEGROUP', 24, None, 'YES', 'varchar', 256, 768, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(256)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'PARTITIONS', 'TABLESPACE_NAME', 25, None, 'YES', 'varchar', 268, 804, None, None, None, 'utf8', 'utf8_bin', 'varchar(268)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'CONSTRAINT_CATALOG', 1, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'CONSTRAINT_SCHEMA', 2, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'CONSTRAINT_NAME', 3, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'UNIQUE_CONSTRAINT_CATALOG', 4, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'UNIQUE_CONSTRAINT_SCHEMA', 5, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'UNIQUE_CONSTRAINT_NAME', 6, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'MATCH_OPTION', 7, None, 'NO', 'enum', 7, 21, None, None, None, 'utf8', 'utf8_bin', "enum('NONE','PARTIAL','FULL')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'UPDATE_RULE', 8, None, 'NO', 'enum', 11, 33, None, None, None, 'utf8', 'utf8_bin', "enum('NO ACTION','RESTRICT','CASCADE','SET NULL','SET DEFAULT')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'DELETE_RULE', 9, None, 'NO', 'enum', 11, 33, None, None, None, 'utf8', 'utf8_bin', "enum('NO ACTION','RESTRICT','CASCADE','SET NULL','SET DEFAULT')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'TABLE_NAME', 10, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'REFERENCED_TABLE_NAME', 11, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'RESOURCE_GROUPS', 'RESOURCE_GROUP_NAME', 1, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'RESOURCE_GROUPS', 'RESOURCE_GROUP_TYPE', 2, None, 'NO', 'enum', 6, 18, None, None, None, 'utf8', 'utf8_bin', "enum('SYSTEM','USER')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'RESOURCE_GROUPS', 'RESOURCE_GROUP_ENABLED', 3, None, 'NO', 'tinyint', None, None, 3, 0, None, None, None, 'tinyint(1)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'RESOURCE_GROUPS', 'VCPU_IDS', 4, None, 'YES', 'blob', 65535, 65535, None, None, None, None, None, 'blob', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'RESOURCE_GROUPS', 'THREAD_PRIORITY', 5, None, 'NO', 'int', None, None, 10, 0, None, None, None, 'int', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'SPECIFIC_NAME', 1, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'ROUTINE_CATALOG', 2, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'ROUTINE_SCHEMA', 3, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'ROUTINE_NAME', 4, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'ROUTINE_TYPE', 5, None, 'NO', 'enum', 9, 27, None, None, None, 'utf8', 'utf8_bin', "enum('FUNCTION','PROCEDURE')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'DATA_TYPE', 6, None, 'YES', 'longtext', 4294967295, 4294967295, None, None, None, 'utf8', 'utf8_bin', 'longtext', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'CHARACTER_MAXIMUM_LENGTH', 7, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'CHARACTER_OCTET_LENGTH', 8, None, 'YES', 'bigint', None, None, 19, 0, None, None, None, 'bigint', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'NUMERIC_PRECISION', 9, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'NUMERIC_SCALE', 10, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'DATETIME_PRECISION', 11, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int unsigned', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'CHARACTER_SET_NAME', 12, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'COLLATION_NAME', 13, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'DTD_IDENTIFIER', 14, None, 'YES', 'longtext', 4294967295, 4294967295, None, None, None, 'utf8', 'utf8_bin', 'longtext', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'ROUTINE_BODY', 15, '', 'NO', 'varchar', 3, 9, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(3)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'ROUTINE_DEFINITION', 16, None, 'YES', 'longtext', 4294967295, 4294967295, None, None, None, 'utf8', 'utf8_bin', 'longtext', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'EXTERNAL_NAME', 17, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'EXTERNAL_LANGUAGE', 18, 'SQL', 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_bin', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'PARAMETER_STYLE', 19, '', 'NO', 'varchar', 3, 9, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(3)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'IS_DETERMINISTIC', 20, '', 'NO', 'varchar', 3, 9, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(3)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'SQL_DATA_ACCESS', 21, None, 'NO', 'enum', 17, 51, None, None, None, 'utf8', 'utf8_bin', "enum('CONTAINS SQL','NO SQL','READS SQL DATA','MODIFIES SQL DATA')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'SQL_PATH', 22, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'SECURITY_TYPE', 23, None, 'NO', 'enum', 7, 21, None, None, None, 'utf8', 'utf8_bin', "enum('DEFAULT','INVOKER','DEFINER')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'CREATED', 24, None, 'NO', 'timestamp', None, None, None, None, 0, None, None, 'timestamp', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'LAST_ALTERED', 25, None, 'NO', 'timestamp', None, None, None, None, 0, None, None, 'timestamp', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'SQL_MODE', 26, None, 'NO', 'set', 520, 1560, None, None, None, 'utf8', 'utf8_bin', "set('REAL_AS_FLOAT','PIPES_AS_CONCAT','ANSI_QUOTES','IGNORE_SPACE','NOT_USED','ONLY_FULL_GROUP_BY','NO_UNSIGNED_SUBTRACTION','NO_DIR_IN_CREATE','NOT_USED_9','NOT_USED_10','NOT_USED_11','NOT_USED_12','NOT_USED_13','NOT_USED_14','NOT_USED_15','NOT_USED_16','NOT_USED_17','NOT_USED_18','ANSI','NO_AUTO_VALUE_ON_ZERO','NO_BACKSLASH_ESCAPES','STRICT_TRANS_TABLES','STRICT_ALL_TABLES','NO_ZERO_IN_DATE','NO_ZERO_DATE','ALLOW_INVALID_DATES','ERROR_FOR_DIVISION_BY_ZERO','TRADITIONAL','NOT_USED_29','HIGH_NOT_PRECEDENCE','NO_ENGINE_SUBSTITUTION','PAD_CHAR_TO_FULL_LENGTH','TIME_TRUNCATE_FRACTIONAL')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'ROUTINE_COMMENT', 27, None, 'NO', 'text', 65535, 65535, None, None, None, 'utf8', 'utf8_bin', 'text', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'DEFINER', 28, None, 'NO', 'varchar', 288, 864, None, None, None, 'utf8', 'utf8_bin', 'varchar(288)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'CHARACTER_SET_CLIENT', 29, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'COLLATION_CONNECTION', 30, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'ROUTINES', 'DATABASE_COLLATION', 31, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'SCHEMATA', 'CATALOG_NAME', 1, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'SCHEMATA', 'SCHEMA_NAME', 2, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'SCHEMATA', 'DEFAULT_CHARACTER_SET_NAME', 3, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'SCHEMATA', 'DEFAULT_COLLATION_NAME', 4, None, 'NO', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'SCHEMATA', 'SQL_PATH', 5, None, 'YES', 'binary', 0, 0, None, None, None, None, None, 'binary(0)', '', '', 'select', '', '', None)
# ('def', 'information_schema', 'SCHEMATA', 'DEFAULT_ENCRYPTION', 6, None, 'NO', 'enum', 3, 9, None, None, None, 'utf8', 'utf8_bin', "enum('NO','YES')", '', '', 'select', '', '', None)
# ('def', 'information_schema', 'SCHEMATA_EXTENSIONS', 'CATALOG_NAME', 1, None, 'YES', 'varchar', 64, 192, None, None, None, 'utf8', 'utf8_tolower_ci', 'varchar(64)', '', '', 'select', '', '', None)
# ...
# ('def', 'mysql_learners', 'chicagopublicschools', 'Phone_Number', 8, None, 'YES', 'varchar', 14, 42, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(14)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Link', 9, None, 'YES', 'varchar', 78, 234, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(78)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Network_Manager', 10, None, 'YES', 'varchar', 40, 120, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(40)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Collaborative_Name', 11, None, 'YES', 'varchar', 34, 102, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(34)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Adequate_Yearly_Progress_Made_', 12, None, 'YES', 'varchar', 30, 90, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(30)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Track_Schedule', 13, None, 'YES', 'varchar', 14, 42, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(14)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'CPS_Performance_Policy_Status', 14, None, 'YES', 'varchar', 29, 87, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(29)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'CPS_Performance_Policy_Level', 15, None, 'YES', 'varchar', 28, 84, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(28)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'HEALTHY_SCHOOL_CERTIFIED', 16, None, 'YES', 'varchar', 24, 72, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(24)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Safety_Icon', 17, None, 'YES', 'varchar', 11, 33, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(11)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'SAFETY_SCORE', 18, None, 'YES', 'varchar', 12, 36, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(12)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Family_Involvement_Icon', 19, None, 'YES', 'varchar', 23, 69, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(23)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Family_Involvement_Score', 20, None, 'YES', 'varchar', 24, 72, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(24)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Environment_Icon', 21, None, 'YES', 'varchar', 30, 90, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(30)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Environment_Score', 22, None, 'YES', 'varchar', 12, 36, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(12)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Instruction_Icon', 23, None, 'YES', 'varchar', 16, 48, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(16)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Instruction_Score', 24, None, 'YES', 'varchar', 12, 36, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(12)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Leaders_Icon', 25, None, 'YES', 'varchar', 12, 36, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(12)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Leaders_Score', 26, None, 'YES', 'varchar', 12, 36, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(12)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Teachers_Icon', 27, None, 'YES', 'varchar', 13, 39, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(13)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Teachers_Score', 28, None, 'YES', 'varchar', 12, 36, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(12)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Parent_Engagement_Icon', 29, None, 'YES', 'varchar', 22, 66, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(22)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Parent_Engagement_Score', 30, None, 'YES', 'varchar', 12, 36, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(12)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Parent_Environment_Icon', 31, None, 'YES', 'varchar', 23, 69, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(23)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Parent_Environment_Score', 32, None, 'YES', 'varchar', 12, 36, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(12)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'AVERAGE_STUDENT_ATTENDANCE', 33, None, 'YES', 'varchar', 26, 78, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(26)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Rate_of_Misconducts__per_100_students_', 34, None, 'YES', 'double', None, None, 22, None, None, None, None, 'double', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Average_Teacher_Attendance', 35, None, 'YES', 'varchar', 26, 78, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(26)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Individualized_Education_Program_Compliance_Rate', 36, None, 'YES', 'varchar', 48, 144, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(48)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Pk_2_Literacy__', 37, None, 'YES', 'varchar', 15, 45, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(15)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Pk_2_Math__', 38, None, 'YES', 'varchar', 11, 33, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(11)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Gr3_5_Grade_Level_Math__', 39, None, 'YES', 'varchar', 24, 72, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(24)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Gr3_5_Grade_Level_Read__', 40, None, 'YES', 'varchar', 24, 72, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(24)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Gr3_5_Keep_Pace_Read__', 41, None, 'YES', 'varchar', 22, 66, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(22)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Gr3_5_Keep_Pace_Math__', 42, None, 'YES', 'varchar', 22, 66, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(22)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Gr6_8_Grade_Level_Math__', 43, None, 'YES', 'varchar', 24, 72, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(24)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Gr6_8_Grade_Level_Read__', 44, None, 'YES', 'varchar', 24, 72, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(24)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Gr6_8_Keep_Pace_Math_', 45, None, 'YES', 'varchar', 21, 63, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(21)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Gr6_8_Keep_Pace_Read__', 46, None, 'YES', 'varchar', 22, 66, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(22)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Gr_8_Explore_Math__', 47, None, 'YES', 'varchar', 19, 57, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(19)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Gr_8_Explore_Read__', 48, None, 'YES', 'varchar', 19, 57, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(19)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'ISAT_Exceeding_Math__', 49, None, 'YES', 'varchar', 21, 63, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(21)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'ISAT_Exceeding_Reading__', 50, None, 'YES', 'varchar', 24, 72, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(24)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'ISAT_Value_Add_Math', 51, None, 'YES', 'varchar', 19, 57, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(19)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'ISAT_Value_Add_Read', 52, None, 'YES', 'varchar', 19, 57, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(19)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'ISAT_Value_Add_Color_Math', 53, None, 'YES', 'varchar', 25, 75, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(25)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'ISAT_Value_Add_Color_Read', 54, None, 'YES', 'varchar', 25, 75, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(25)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Students_Taking__Algebra__', 55, None, 'YES', 'varchar', 26, 78, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(26)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Students_Passing__Algebra__', 56, None, 'YES', 'varchar', 27, 81, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(27)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', '9th Grade EXPLORE (2009)', 57, None, 'YES', 'varchar', 24, 72, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(24)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', '9th Grade EXPLORE (2010)', 58, None, 'YES', 'varchar', 24, 72, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(24)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', '10th Grade PLAN (2009)', 59, None, 'YES', 'varchar', 22, 66, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(22)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', '10th Grade PLAN (2010)', 60, None, 'YES', 'varchar', 22, 66, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(22)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Net_Change_EXPLORE_and_PLAN', 61, None, 'YES', 'varchar', 27, 81, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(27)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', '11th Grade Average ACT (2011)', 62, None, 'YES', 'varchar', 29, 87, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(29)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Net_Change_PLAN_and_ACT', 63, None, 'YES', 'varchar', 23, 69, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(23)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'College_Eligibility__', 64, None, 'YES', 'varchar', 21, 63, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(21)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Graduation_Rate__', 65, None, 'YES', 'varchar', 17, 51, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(17)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'College_Enrollment_Rate__', 66, None, 'YES', 'varchar', 25, 75, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(25)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'COLLEGE_ENROLLMENT', 67, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'General_Services_Route', 68, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Freshman_on_Track_Rate__', 69, None, 'YES', 'varchar', 24, 72, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(24)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'X_COORDINATE', 70, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Y_COORDINATE', 71, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Latitude', 72, None, 'YES', 'double', None, None, 22, None, None, None, None, 'double', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Longitude', 73, None, 'YES', 'double', None, None, 22, None, None, None, None, 'double', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'COMMUNITY_AREA_NUMBER', 74, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'COMMUNITY_AREA_NAME', 75, None, 'YES', 'varchar', 22, 66, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(22)', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Ward', 76, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Police_District', 77, None, 'YES', 'int', None, None, 10, 0, None, None, None, 'int', '', '', 'select,insert,update,references', '', '', None)
# ('def', 'mysql_learners', 'chicagopublicschools', 'Location', 78, None, 'YES', 'varchar', 27, 81, None, None, None, 'utf8', 'utf8_general_ci', 'varchar(27)', '', '', 'select,insert,update,references', '', '', None)

# %% [markdown]
# Now retrieve the the list of columns in SCHOOLS table and their column type (datatype) and length.

# %%
query = 'SELECT column_name, column_type \
  FROM information_schema.columns \
  WHERE (table_name = \'chicagopublicschools\')\
  order by ordinal_position;'

try:
    cursor.execute(query)
    
except Error as e:
    print("select query Filed", e)
else:
    print("select query Succeded")
# Out:
# select query Succeded

# %%
columns = cursor.fetchall()

for column in columns:
    print(column)
# Out:
# ('School_ID', 'int')
# ('NAME_OF_SCHOOL', 'varchar(65)')
# ('Elementary, Middle, or High School', 'varchar(34)')
# ('Street_Address', 'varchar(29)')
# ('City', 'varchar(7)')
# ('State', 'varchar(5)')
# ('ZIP_Code', 'int')
# ('Phone_Number', 'varchar(14)')
# ('Link', 'varchar(78)')
# ('Network_Manager', 'varchar(40)')
# ('Collaborative_Name', 'varchar(34)')
# ('Adequate_Yearly_Progress_Made_', 'varchar(30)')
# ('Track_Schedule', 'varchar(14)')
# ('CPS_Performance_Policy_Status', 'varchar(29)')
# ('CPS_Performance_Policy_Level', 'varchar(28)')
# ('HEALTHY_SCHOOL_CERTIFIED', 'varchar(24)')
# ('Safety_Icon', 'varchar(11)')
# ('SAFETY_SCORE', 'varchar(12)')
# ('Family_Involvement_Icon', 'varchar(23)')
# ('Family_Involvement_Score', 'varchar(24)')
# ('Environment_Icon', 'varchar(30)')
# ('Environment_Score', 'varchar(12)')
# ('Instruction_Icon', 'varchar(16)')
# ('Instruction_Score', 'varchar(12)')
# ('Leaders_Icon', 'varchar(12)')
# ('Leaders_Score', 'varchar(12)')
# ('Teachers_Icon', 'varchar(13)')
# ('Teachers_Score', 'varchar(12)')
# ('Parent_Engagement_Icon', 'varchar(22)')
# ('Parent_Engagement_Score', 'varchar(12)')
# ('Parent_Environment_Icon', 'varchar(23)')
# ('Parent_Environment_Score', 'varchar(12)')
# ('AVERAGE_STUDENT_ATTENDANCE', 'varchar(26)')
# ('Rate_of_Misconducts__per_100_students_', 'double')
# ('Average_Teacher_Attendance', 'varchar(26)')
# ('Individualized_Education_Program_Compliance_Rate', 'varchar(48)')
# ('Pk_2_Literacy__', 'varchar(15)')
# ('Pk_2_Math__', 'varchar(11)')
# ('Gr3_5_Grade_Level_Math__', 'varchar(24)')
# ('Gr3_5_Grade_Level_Read__', 'varchar(24)')
# ('Gr3_5_Keep_Pace_Read__', 'varchar(22)')
# ('Gr3_5_Keep_Pace_Math__', 'varchar(22)')
# ('Gr6_8_Grade_Level_Math__', 'varchar(24)')
# ('Gr6_8_Grade_Level_Read__', 'varchar(24)')
# ('Gr6_8_Keep_Pace_Math_', 'varchar(21)')
# ('Gr6_8_Keep_Pace_Read__', 'varchar(22)')
# ('Gr_8_Explore_Math__', 'varchar(19)')
# ('Gr_8_Explore_Read__', 'varchar(19)')
# ('ISAT_Exceeding_Math__', 'varchar(21)')
# ('ISAT_Exceeding_Reading__', 'varchar(24)')
# ('ISAT_Value_Add_Math', 'varchar(19)')
# ('ISAT_Value_Add_Read', 'varchar(19)')
# ('ISAT_Value_Add_Color_Math', 'varchar(25)')
# ('ISAT_Value_Add_Color_Read', 'varchar(25)')
# ('Students_Taking__Algebra__', 'varchar(26)')
# ('Students_Passing__Algebra__', 'varchar(27)')
# ('9th Grade EXPLORE (2009)', 'varchar(24)')
# ('9th Grade EXPLORE (2010)', 'varchar(24)')
# ('10th Grade PLAN (2009)', 'varchar(22)')
# ('10th Grade PLAN (2010)', 'varchar(22)')
# ('Net_Change_EXPLORE_and_PLAN', 'varchar(27)')
# ('11th Grade Average ACT (2011)', 'varchar(29)')
# ('Net_Change_PLAN_and_ACT', 'varchar(23)')
# ('College_Eligibility__', 'varchar(21)')
# ('Graduation_Rate__', 'varchar(17)')
# ('College_Enrollment_Rate__', 'varchar(25)')
# ('COLLEGE_ENROLLMENT', 'int')
# ('General_Services_Route', 'int')
# ('Freshman_on_Track_Rate__', 'varchar(24)')
# ('X_COORDINATE', 'int')
# ('Y_COORDINATE', 'int')
# ('Latitude', 'double')
# ('Longitude', 'double')
# ('COMMUNITY_AREA_NUMBER', 'int')
# ('COMMUNITY_AREA_NAME', 'varchar(22)')
# ('Ward', 'int')
# ('Police_District', 'int')
# ('Location', 'varchar(27)')

# %% [markdown]
# ## Problems
#
# ### Problem 1
#
# ##### How many Elementary Schools are in the dataset?

# %%
# %sql mysql+pymysql://root:@localhost/mysql_learners

# %%
# %%sql
#
# select count(*) from chicagopublicschools where `Elementary, Middle, or High School` = 'ES';
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 1 rows affected.
# [(462,)]

# %% [markdown]
# ### Problem 2
#
# ##### What is the highest Safety Score?

# %%
# %%sql
# select max(SAFETY_SCORE) from chicagopublicschools;
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 1 rows affected.
# [('99',)]

# %% [markdown]
# ### Problem 3
#
# ##### Which schools have highest Safety Score?

# %%
# %%sql
# select NAME_OF_SCHOOL
# from chicagopublicschools
# where SAFETY_SCORE = (select max(SAFETY_SCORE) from chicagopublicschools);
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 19 rows affected.
# [('Abraham Lincoln Elementary School',),
#  ('Alexander Graham Bell Elementary School',),
#  ('Annie Keller Elementary Gifted Magnet School',),
#  ('Augustus H Burley Elementary School',),
#  ('Edgar Allan Poe Elementary Classical School',),
#  ('Edgebrook Elementary School',),
#  ('Ellen Mitchell Elementary School',),
#  ('James E McDade Elementary Classical School',),
#  ('James G Blaine Elementary School',),
#  ('LaSalle Elementary Language Academy',),
#  ('Mary E Courtenay Elementary Language Arts Center',),
#  ('Northside College Preparatory High School',),
#  ('Northside Learning Center High School',),
#  ('Norwood Park Elementary School',),
#  ('Oriole Park Elementary School',),
#  ('Sauganash Elementary School',),
#  ('Stephen Decatur Classical Elementary School',),
#  ('Talman Elementary School',),
#  ('Wildwood Elementary School',)]

# %% [markdown]
# ### Problem 4
#
# ##### What are the top 10 schools with the highest "Average Student Attendance"?

# %%
# %%sql
# select NAME_OF_SCHOOL ,AVERAGE_STUDENT_ATTENDANCE
# from chicagopublicschools
# order by AVERAGE_STUDENT_ATTENDANCE desc
# limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 10 rows affected.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %% [markdown]
# ### Problem 5
#
# ##### Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance

# %%
# %%sql
# select NAME_OF_SCHOOL ,AVERAGE_STUDENT_ATTENDANCE
# from chicagopublicschools
# order by AVERAGE_STUDENT_ATTENDANCE
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 5 rows affected.
# [('Velma F Thomas Early Childhood Center', ''),
#  ('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%')]

# %% [markdown]
# ### Problem 6
#
# ##### Now remove the '%' sign from the above result set for Average Student Attendance column

# %%
# %%sql
# select NAME_OF_SCHOOL , SUBSTRING(AVERAGE_STUDENT_ATTENDANCE,1 , 5)
# from chicagopublicschools
# order by AVERAGE_STUDENT_ATTENDANCE
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 5 rows affected.
# [('Velma F Thomas Early Childhood Center', ''),
#  ('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00')]

# %% [markdown]
# ### Problem 7
#
# ##### Which Schools have Average Student Attendance lower than 70%?

# %%
# %%sql
# select NAME_OF_SCHOOL , AVERAGE_STUDENT_ATTENDANCE
# from chicagopublicschools
# where SUBSTRING(AVERAGE_STUDENT_ATTENDANCE,1 , 5) <  70.00
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 5 rows affected.
# [('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Dyett High School', '62.50%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Orr Academy High School', '66.30%')]

# %%
# %%sql
# select NAME_OF_SCHOOL , AVERAGE_STUDENT_ATTENDANCE
# from chicagopublicschools
# where cast(SUBSTRING(AVERAGE_STUDENT_ATTENDANCE,1 , 5) as double) <  70.00
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 5 rows affected.
# [('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Dyett High School', '62.50%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Orr Academy High School', '66.30%')]

# %% [markdown]
# ### Problem 8
#
# ##### Get the total College Enrollment for each Community Area

# %%
# %%sql
# select sum(COLLEGE_ENROLLMENT)
# from chicagopublicschools
# group by COMMUNITY_AREA_NAME;
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 77 rows affected.
# [(Decimal('5615'),),
#  (Decimal('4543'),),
#  (Decimal('6483'),),
#  (Decimal('7922'),),
#  (Decimal('1458'),),
#  (Decimal('6864'),),
#  (Decimal('7541'),),
#  (Decimal('9429'),),
#  (Decimal('7055'),),
#  (Decimal('7020'),),
#  (Decimal('8620'),),
#  (Decimal('1636'),),
#  (Decimal('5337'),),
#  (Decimal('5146'),),
#  (Decimal('1568'),),
#  (Decimal('7351'),),
#  (Decimal('6832'),),
#  (Decimal('4206'),),
#  (Decimal('7975'),),
#  (Decimal('5946'),),
#  (Decimal('2091'),),
#  (Decimal('2809'),),
#  (Decimal('4287'),),
#  (Decimal('4043'),),
#  (Decimal('5042'),),
#  (Decimal('4568'),),
#  (Decimal('10933'),),
#  (Decimal('1522'),),
#  (Decimal('3271'),),
#  (Decimal('14386'),),
#  (Decimal('7257'),),
#  (Decimal('2648'),),
#  (Decimal('2085'),),
#  (Decimal('1930'),),
#  (Decimal('9647'),),
#  (Decimal('1859'),),
#  (Decimal('7764'),),
#  (Decimal('3640'),),
#  (Decimal('14793'),),
#  (Decimal('4006'),),
#  (Decimal('3167'),),
#  (Decimal('4051'),),
#  (Decimal('2622'),),
#  (Decimal('4670'),),
#  (Decimal('910'),),
#  (Decimal('4175'),),
#  (Decimal('7086'),),
#  (Decimal('8197'),),
#  (Decimal('6469'),),
#  (Decimal('5305'),),
#  (Decimal('1620'),),
#  (Decimal('1431'),),
#  (Decimal('1552'),),
#  (Decimal('3362'),),
#  (Decimal('4207'),),
#  (Decimal('3240'),),
#  (Decimal('6954'),),
#  (Decimal('4132'),),
#  (Decimal('9915'),),
#  (Decimal('4068'),),
#  (Decimal('786'),),
#  (Decimal('3700'),),
#  (Decimal('531'),),
#  (Decimal('4210'),),
#  (Decimal('4600'),),
#  (Decimal('1547'),),
#  (Decimal('4388'),),
#  (Decimal('549'),),
#  (Decimal('963'),),
#  (Decimal('140'),),
#  (Decimal('1755'),),
#  (Decimal('3975'),),
#  (Decimal('4552'),),
#  (Decimal('1317'),),
#  (Decimal('4823'),),
#  (Decimal('1378'),),
#  (Decimal('871'),)]

# %% [markdown]
# ### Problem 9
#
# ##### Get the 5 Community Areas with the least total College Enrollment  sorted in ascending order

# %%
# %%sql
# select Community_Area_Name, sum(COLLEGE_ENROLLMENT) as TOTAL_ENROLLMENT
# from chicagopublicschools
# group by COMMUNITY_AREA_NAME
# order by TOTAL_ENROLLMENT
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 5 rows affected.
# [('OAKLAND', Decimal('140')),
#  ('FULLER PARK', Decimal('531')),
#  ('BURNSIDE', Decimal('549')),
#  ('OHARE', Decimal('786')),
#  ('LOOP', Decimal('871'))]

# %% [markdown]
# ### Problem 10
#
# ##### List 5 schools with lowest safety score.

# %%
# %%sql
# select name_of_school , safety_score
# from chicagopublicschools
# order by safety_score
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 5 rows affected.
# [('Blair Early Childhood Center', ''),
#  ('Barbara Vick Early Childhood & Family Center', ''),
#  ('Cyrus H McCormick Elementary School', ''),
#  ('Ariel Elementary Community Academy', ''),
#  ('Arthur R Ashe Elementary School', '')]

# %% [markdown]
# ### Problem 11
#
# ##### Get the hardship index for the community area which has College Enrollment of 4368

# %%
# %%sql
# select hardship_index
# from chicago_socioeconomic_data as CD, chicagopublicschools as CPS
# where CD.ca = CPS.community_area_number
# and college_enrollment = 4368;
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 1 rows affected.
# [(6.0,)]

# %% [markdown]
# ### Problem 12
#
# ##### Get the hardship index for the community area which has the school with the  highest enrollment.

# %%
# %%sql
# select hardship_index
# from chicago_socioeconomic_data as CD, chicagopublicschools as CPS
# where CD.ca = CPS.community_area_number
# and college_enrollment = (select max(college_enrollment) from chicagopublicschools);
# Out:
#  * mysql+pymysql://root:***@localhost/mysql_learners
# 1 rows affected.
# [(6.0,)]
